# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
iris = skl.datasets.load_iris()

# %%
# Independent Features
X = pd.DataFrame(iris["data"], columns=iris.feature_names)

# %%
# Dependent Features
y = iris["target"]

# %%
# Train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=36
)

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

treeClassifier = DecisionTreeClassifier()

# %%
treeClassifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Visualize Decision Tree
skl.tree.plot_tree(treeClassifier, filled=True)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [42, 39, 39]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(0.35, 0.8333333333333333, 'True  '),
#  Text(0.5, 0.75, 'x[3] <= 1.65\ngini = 0.5\nsamples = 78\nvalue = [0, 39, 39]'),
#  Text(0.45, 0.8333333333333333, '  False'),
#  Text(0.2, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.172\nsamples = 42\nvalue = [0, 38, 4]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[0] <= 6.05\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.2, 0.25, 'x[3] <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.1, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
y_pred = treeClassifier.predict(X_test)

# %%
print(f'Confusion Matrix: \n{skl.metrics.confusion_matrix(y_test,y_pred)}')
print(f'Accuracy Score: {skl.metrics.accuracy_score(y_test,y_pred)}')
print(f'Classification Report: \n{skl.metrics.classification_report(y_test,y_pred)}')
# Out:
# Confusion Matrix:
# [[ 8  0  0]
#  [ 0 10  1]
#  [ 0  0 11]]
# Accuracy Score: 0.9666666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## Prepruning and Hyperparameter tuning

# %%
params_grid = {
    "criterion": ["gini", "entropy", "log_loss"],
    "splitter": ["best", "random"],
    "max_depth": [1, 2, 3, 4, 5],
    "max_features": ["auto", "sqrt", "log2"]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(treeClassifier,param_grid=params_grid,cv=5,scoring='accuracy')

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
y_pred = grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
grid.best_score_
# Out:
# np.float64(0.975)

# %%
print(f'Confusion Matrix: \n{skl.metrics.confusion_matrix(y_test,y_pred)}')
print(f'Accuracy Score: {skl.metrics.accuracy_score(y_test,y_pred)}')
print(f'Classification Report: \n{skl.metrics.classification_report(y_test,y_pred)}')
# Out:
# Confusion Matrix:
# [[ 8  0  0]
#  [ 0 10  1]
#  [ 0  0 11]]
# Accuracy Score: 0.9666666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
